# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# PSeudoCódigo
#
# 1-grafo  = {}
#
#
#
# 2-Se crea lista visitados y Lista cola
#
# 3-Variable origen para empezar recorrido
#
# 4- SE COLOCA EL VÉRTICE ORIGEN EN UNA COLA
#
# 5-MIENTRAS LA COLA NO ESTE VACÍA
#
# 6- creamos bucle while para recorrer la cola
#
# 7- DESENCOLAR UN VÉRTICE, ESTE SERÁ AHORA EL VÉRTICE ACTUAL
#
# 8- SI EL VÉRTICE ACTUAL NO HA SIDO VISITADO Se visita
#
# 9- PROCESAR (IMPRIMIR) EL VÉRTICE ACTUAL
#
# 10- PARA CADA VÉRTICE QUE EL VÉRTICE ACTUAL TIENE COMO DESTINO, Y QUE NO HA SIDO VISITADO:ENCOLAR EL VERTICE

# %% [markdown]
# Proceso
#
# ![image.png](data:image/png;base64,...)

# %%
#Codigo

grafo = {'1': [('2',2), ('3',3), ('4',4)],
         	'2': [('5',5), ('6',6)],
			'3': [('7',7)],
			'4': [('8', 8),('9', 9)],
                        '5': [('2', 2)],
                        '6': [('10', 10)],
                        '7': [('3', 3)],
                        '8': [('4', 4)],
                        '9': [('4', 4)],
                        '10': [('6', 6)] 
         }
         
		
       
visitados = []
cola = []

origen = '1'
print("\nLista de recorrido en amplitud\n")
cola.append(origen)
while cola:
	actual = cola.pop(0)

	if actual not in visitados:
		print("Vertice actual -> ", actual)
		visitados.append(actual)
	for key, lista in grafo[actual]:
		if key not in visitados:
			cola.append(key)
# Out:
# Lista de recorrido en amplitud
#
# Vertice actual ->  1
# Vertice actual ->  2
# Vertice actual ->  3
# Vertice actual ->  4
# Vertice actual ->  5
# Vertice actual ->  6
# Vertice actual ->  7
# Vertice actual ->  8
# Vertice actual ->  9
# Vertice actual ->  10
